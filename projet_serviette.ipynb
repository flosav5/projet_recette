# %%
import pandas as pd


# Lecture du fichier Excel avec Pandas
df_ingre = pd.read_excel('data/produit_alimentaire.xlsm', sheet_name="Detail ingredient")
df_etape=pd.read_excel('data/produit_alimentaire.xlsm', sheet_name="Detail etape")
df_synth=pd.read_excel('data/produit_alimentaire.xlsm', sheet_name="Synthese")

# %%
df_etape.head()
# Out:
#   Unnamed: 0   Unnamed: 1  \
# 0        NaN          NaN
# 1   Code AGB  Code CIQUAL
# 2      11084        11084
# 3      11023        11023
# 4      11000        11000
#
#   Résultats par étape\nL'arrondi des données peut causer des différences entre la somme des 6 étapes et la Synthèse.\nLa valeur zéro est exprimée "-"  \
# 0                                                NaN
# 1                                   Groupe d'aliment
# 2             aides culinaires et ingrédients divers
# 3             aides culinaires et ingrédients divers
# 4             aides culinaires et ingrédients divers
#
#               Unnamed: 3                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# ...

# %%
df_synth.head()
# Out:
#   Unnamed: 0    Unnamed: 1                              Unnamed: 2  \
# 0        NaN           NaN                                     NaN
# 1  Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2      11084         11084  aides culinaires et ingrédients divers
# 3      11023         11023  aides culinaires et ingrédients divers
# 4      11000         11000  aides culinaires et ingrédients divers
#
#                 Synthèse                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# 4                 herbes                    Ail, cru          Garlic, fresh
#
#                                           Unnamed: 6  \
# ...

# %%
df_synth.head()
# Out:
#   Unnamed: 0    Unnamed: 1                              Unnamed: 2  \
# 0        NaN           NaN                                     NaN
# 1  Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2      11084         11084  aides culinaires et ingrédients divers
# 3      11023         11023  aides culinaires et ingrédients divers
# 4      11000         11000  aides culinaires et ingrédients divers
#
#                 Synthèse                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# 4                 herbes                    Ail, cru          Garlic, fresh
#
#                                           Unnamed: 6  \
# ...

# %%
df_etape.drop([0], inplace=True)
df_etape = df_etape.reset_index(drop=True)
df_etape.columns = df_etape.iloc[0]


df_etape.drop([0], inplace=True)
df_etape = df_etape.reset_index(drop=True)
df_etape
# Out:
# 0    Code AGB Code CIQUAL                        Groupe d'aliment  \
# 0       11084       11084  aides culinaires et ingrédients divers
# 1       11023       11023  aides culinaires et ingrédients divers
# 2       11000       11000  aides culinaires et ingrédients divers
# 3       11093       11093  aides culinaires et ingrédients divers
# 4       20995       20995  aides culinaires et ingrédients divers
# ...       ...         ...                                     ...
# 2512     6535        6535                 viandes, œufs, poissons
# 2513     6582        6582                 viandes, œufs, poissons
# 2514    26146       26146                 viandes, œufs, poissons
# 2515    26147       26147                 viandes, œufs, poissons
# 2516    25512       25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...

# %%
df_synth.drop([0], inplace=True)
df_synth = df_synth.reset_index(drop=True)
df_synth.columns = df_synth.iloc[0]


df_synth.drop([0], inplace=True)
df_synth = df_synth.reset_index(drop=True)
df_synth
# Out:
# 0    Code\nAGB Code\nCIQUAL                        Groupe d'aliment  \
# 0        11084        11084  aides culinaires et ingrédients divers
# 1        11023        11023  aides culinaires et ingrédients divers
# 2        11000        11000  aides culinaires et ingrédients divers
# 3        11093        11093  aides culinaires et ingrédients divers
# 4        20995        20995  aides culinaires et ingrédients divers
# ...        ...          ...                                     ...
# 2512      6535         6535                 viandes, œufs, poissons
# 2513      6582         6582                 viandes, œufs, poissons
# 2514     26146        26146                 viandes, œufs, poissons
# 2515     26147        26147                 viandes, œufs, poissons
# 2516     25512        25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# ...

# %%
df_etape = df_etape.iloc[:, 0:14]
df_etape
# Out:
# 0    Code AGB Code CIQUAL                        Groupe d'aliment  \
# 0       11084       11084  aides culinaires et ingrédients divers
# 1       11023       11023  aides culinaires et ingrédients divers
# 2       11000       11000  aides culinaires et ingrédients divers
# 3       11093       11093  aides culinaires et ingrédients divers
# 4       20995       20995  aides culinaires et ingrédients divers
# ...       ...         ...                                     ...
# 2512     6535        6535                 viandes, œufs, poissons
# 2513     6582        6582                 viandes, œufs, poissons
# 2514    26146       26146                 viandes, œufs, poissons
# 2515    26147       26147                 viandes, œufs, poissons
# 2516    25512       25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...

# %%
df_synth = df_synth.iloc[:, 0:14]
df_synth
# Out:
# 0    Code\nAGB Code\nCIQUAL                        Groupe d'aliment  \
# 0        11084        11084  aides culinaires et ingrédients divers
# 1        11023        11023  aides culinaires et ingrédients divers
# 2        11000        11000  aides culinaires et ingrédients divers
# 3        11093        11093  aides culinaires et ingrédients divers
# 4        20995        20995  aides culinaires et ingrédients divers
# ...        ...          ...                                     ...
# 2512      6535         6535                 viandes, œufs, poissons
# 2513      6582         6582                 viandes, œufs, poissons
# 2514     26146        26146                 viandes, œufs, poissons
# 2515     26147        26147                 viandes, œufs, poissons
# 2516     25512        25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# ...

# %%
df_synth.to_csv('data/synth.csv',index=False)

# %%
df_etape.to_csv('data/etape.csv',index=False)

# %%
doublons = df_synth_code['Code\nAGB'].astype(str) != df_synth_code['Code\nCIQUAL'].astype(str)

print(f"A t-on des doublons entre les 2 colonnes ? {all(doublons)}")
# Out:
# A t-on des doublons entre les 2 colonnes ? False

# %%
 df_synth[doublons][['Code\nAGB', 'Code\nCIQUAL']]
# Out:
# 0    Code\nAGB Code\nCIQUAL
# 443    25415_2        25415
# 479    25415_1        25415
# 711     7815_2         7815
# 816    13024_2        13082
# 870    13014_2        13014
# 871    13014_3        13014
# 872    13014_1        13014
# 909    20061_2        20061
# 911    20061_1        20061
# 958    13024_1        13024
# 959    13025_2        13025
# 960    13025_1        13025
# 1121   20047_2        20047
# 1122   20047_3        20047
# 1126   20047_1        20047
# 1360    1029_1         1029
# 1361    1029_2         1029
# 1775    9340_2         9340
# 1776    9341_2         9341
# 1777    9341_1         9341
# 1778    9340_1         9340
# 1815    7815_1         7815
# 2346   20591_1        20591
# 2347   20591_2        20591
