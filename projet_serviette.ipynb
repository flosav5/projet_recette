# %%
import pandas as pd


# Lecture du fichier Excel avec Pandas
df = pd.read_excel('data/produit_alimentaire', sheet_name="Detail ingredient")

# Affichage du DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5092\2864959086.py in <module>
#       3
#       4 # Lecture du fichier Excel avec Pandas
# ----> 5 df = pd.read_excel('data/produit_alimentaire', sheet_name="Detail ingredient")
#       6
#       7 # Affichage du DataFrame
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# ...

# %%
df.tail()
# Out:
#    Unnamed: 0  \
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
#
# ...

# %%
print(f"Notre fichier csv contient {df.shape[1]} colonnes.")
print(f"Notre fichier csv contient {df.shape[0]} lignes.")
# Out:
# Notre fichier csv contient 2 colonnes.
# Notre fichier csv contient 9 lignes.
